# %% [markdown]
# Columns
#
# 1.  **Airline** - This contains the name of the airline company.
# 2.   **Date_of_Journey**- This contain the journey starting date
# 3.   **Source**-  This contain the place frome where the journey started.
# 4.   **Destination** - This contain places of destination
# 5.   **Route**-  This contain the route of flight
# 6.   **Dep_Time**- This contaion the departure time of flight.
# 7.   **Arrival_Time**- This contain the arrival time of flight.
# 8.   **Duration**- This is the time taken by plane to reach destination.
# 9.   **Total_Stops**- This contains the number of stops before reaching the destination.
# 10.  **Addtional_Info**- This contain aditional information of flight.
# 11.  Price- This contain the price of the flight

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data_train

# %%
 # to fetch excel file

train_data=pd.read_excel('Data_Train.xlsx')

# %%
# to display all the columns

pd.set_option('display.max_columns',None)

# %%
train_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# to get information column's datatypes

train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
# to see different values and its frequency

train_data['Duration'].value_counts()
# Out:
# 2h 50m     550
# 1h 30m     386
# 2h 55m     337
# 2h 45m     337
# 2h 35m     329
#           ...
# 41h 20m      1
# 47h          1
# 35h 35m      1
# 47h 40m      1
# 32h 20m      1
# Name: Duration, Length: 368, dtype: int64

# %%
 # to check null values

train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
 # shape of DataFrame

train_data.shape
# Out:
# (10683, 11)

# %%
# Removing the null values 

train_data.dropna(inplace=True)

# %%
 #Removing the Duplicates value

train_data.drop_duplicates(inplace=True)

# %%
# to index each rows again

train_data.reset_index(inplace=True,drop=True)

# %%
# Final shape after removing null and duplicates values

train_data.shape
# Out:
# (10462, 11)

# %%
# Recheck for null values

train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10462 entries, 0 to 10461
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10462 non-null  object
#  1   Date_of_Journey  10462 non-null  object
#  2   Source           10462 non-null  object
#  3   Destination      10462 non-null  object
#  4   Route            10462 non-null  object
#  5   Dep_Time         10462 non-null  object
#  6   Arrival_Time     10462 non-null  object
#  7   Duration         10462 non-null  object
#  8   Total_Stops      10462 non-null  object
#  9   Additional_Info  10462 non-null  object
#  10  Price            10462 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 899.2+ KB

# %% [markdown]
# # convert the object datatypes to useful datatypes

# %% [markdown]
# working on 'Journey_day' column

# %%
train_data['Journey_day']=pd.to_datetime(train_data.Date_of_Journey,dayfirst=True).dt.day

# %%
train_data['Journey_month']=pd.to_datetime(train_data.Date_of_Journey, dayfirst=True).dt.month

# %%
# Since year value is same, we will not consider it
#train_data['Journey_year']=pd.to_datetime(train_data.Date_of_Journey, dayfirst=True).dt.year

# %%
train_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_day  Journey_month
# 0           24              3
# 1            1              5
# ...

# %%
# After fetching all the information from Date_of_Journey column, so it doesn't require 
train_data.drop(columns=['Date_of_Journey'], inplace=True)

# %%
# Value distribution
train_data.Journey_day.value_counts()
# Out:
# 9     1375
# 6     1268
# 27    1092
# 21    1085
# 1     1058
# 24    1022
# 15     967
# 12     946
# 3      835
# 18     814
# Name: Journey_day, dtype: int64

# %%
# value distribution of Journey_day can be visualize
sns.distplot(train_data['Journey_day'])
sns.boxplot(y=train_data['Journey_day'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Value distribution
train_data.Journey_month.value_counts()
# Out:
# 5    3395
# 6    3311
# 3    2678
# 4    1078
# Name: Journey_month, dtype: int64

# %%
# value distribution of Journey_month can be visualize
sns.distplot(train_data['Journey_month'])
sns.boxplot(y=train_data['Journey_month'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# working on 'Dep_Time' column

# %%
# Convert Dep_Time into datetime and extract values

# Extracting Hours
train_data['Dep_hour']=pd.to_datetime(train_data.Dep_Time).dt.hour

# Extracting Minutes
train_data['Dep_min']=pd.to_datetime(train_data.Dep_Time).dt.minute

# %%
# Remove the Dep_Time column
train_data.drop(columns=['Dep_Time'],inplace=True)

# %%
train_data.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            1              5
# 2      19h     2 stops         No info  13882            9              6
# 3   5h 25m      1 stop         No info   6218           12              5
# 4   4h 45m      1 stop         No info  13302            1              3
#
#    Dep_hour  Dep_min
# 0        22       20
# 1         5       50
# ...

# %%
# value distribution
train_data.Dep_hour.value_counts()
# Out:
# 9     886
# 7     863
# 8     694
# 17    689
# 6     675
# 20    649
# 5     582
# 11    579
# 19    544
# 10    527
# 14    505
# 21    489
# 16    461
# 18    441
# 13    411
# 22    373
# 15    319
# 2     194
# 12    178
# 4     169
# 23    133
# 0      40
# 1      37
# 3      24
# Name: Dep_hour, dtype: int64

# %%
# value distribution of Dep_hour can be visualize
sns.distplot(train_data['Dep_hour'])
sns.boxplot(y=train_data['Dep_hour'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# value distribution
train_data.Dep_min.value_counts()
# Out:
# 0     2039
# 30    1173
# 55    1052
# 10     870
# 45     857
# 5      740
# 15     684
# 25     679
# 20     664
# 35     645
# 50     586
# 40     473
# Name: Dep_min, dtype: int64

# %%
# value distribution of Dep_min can be visualize
sns.distplot(train_data['Dep_min'])
sns.boxplot(y=train_data['Dep_min'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# working on 'Arrival_Time' column

# %%
# Convert Arrival_time into datetime and extract values

# Extracting Hours
train_data['Arrival_hour']=pd.to_datetime(train_data.Arrival_Time).dt.hour

# Extracting Minutes
train_data['Arrival_min']=pd.to_datetime(train_data.Arrival_Time).dt.minute

# %%
# Removing Arrival_Time column
train_data.drop('Arrival_Time',axis=1,inplace=True)

# %%
train_data.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Journey_day  Journey_month  Dep_hour  \
# 0    non-stop         No info   3897           24              3        22
# 1     2 stops         No info   7662            1              5         5
# 2     2 stops         No info  13882            9              6         9
# 3      1 stop         No info   6218           12              5        18
# 4      1 stop         No info  13302            1              3        16
#
#    Dep_min  Arrival_hour  Arrival_min
# 0       20             1           10
# ...

# %%
# value distribution
train_data.Arrival_hour.value_counts()
# Out:
# 19    1554
# 12     861
# 4      761
# 21     701
# 22     646
# 1      525
# 18     509
# 9      489
# 23     481
# 10     474
# 8      468
# 7      414
# 20     377
# 16     370
# 0      322
# 13     303
# 11     297
# 14     294
# 17     191
# 15     182
# 2       79
# 5       66
# 6       51
# 3       47
# Name: Arrival_hour, dtype: int64

# %%
# value distribution of Arrival_hour can be visualize
sns.distplot(train_data['Arrival_hour'])
sns.boxplot(y=train_data['Arrival_hour'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# value distribution
train_data.Arrival_min.value_counts()
# Out:
# 0     1417
# 15    1245
# 25    1224
# 35    1070
# 20     894
# 30     831
# 50     744
# 45     689
# 5      659
# 40     626
# 10     576
# 55     487
# Name: Arrival_min, dtype: int64

# %%
# value distribution of Arrival_min can be visualize
sns.distplot(train_data['Arrival_min'])
sns.boxplot(y=train_data['Arrival_min'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# working on 'Duration' column

# %%
# to make hour and minute columns separately from Duration column

duration = list(train_data['Duration'])

for i in range(len(duration)):
  if len(duration[i].split()) !=2:                # checks if duration contain only hour or min
    if 'h' in duration[i]:
      duration[i] = duration[i].strip() + ' 0m'   # add 0 minute
    else:
      duration[i] = '0h ' + duration[i]           # add 0 hour
  else:
    continue

duration_hour=[]
duration_min=[]
for i in range(len(duration)):
  duration_hour.append(int(duration[i].split('h')[0]))                     # Extract hour from duration
  duration_min.append(int(duration[i].split()[1].split('m')[0]))           # Extract minute from duration

# %%
# Make columns and assigning the values

train_data['Duration_hours']=duration_hour
train_data['Duration_mins']=duration_min

# %%
# Remove Duration column

train_data.drop(columns=['Duration'],inplace=True)

# %%
train_data.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0         No info   3897           24              3        22       20
# 1         No info   7662            1              5         5       50
# 2         No info  13882            9              6         9       25
# 3         No info   6218           12              5        18        5
# 4         No info  13302            1              3        16       50
#
#    Arrival_hour  Arrival_min  Duration_hours  Duration_mins
# ...

# %%
# Value distribution
train_data.Duration_hours.value_counts()
# Out:
# 2     2387
# 1      621
# 3      500
# 7      487
# 5      481
# 9      445
# 12     426
# 8      424
# 13     381
# 11     365
# 10     355
# 6      340
# 14     337
# 15     262
# 23     240
# 16     234
# 4      222
# 26     214
# 24     195
# 25     183
# 22     181
# 27     174
# 21     172
# 20     161
# 18     130
# 17     128
# 19     125
# 28      93
# 29      50
# 30      49
# 38      31
# 37      17
# 33      10
# 32       9
# 35       7
# 34       7
# 31       6
# 36       5
# 47       2
# 42       2
# 40       1
# 41       1
# 39       1
# 0        1
# Name: Duration_hours, dtype: int64

# %%
# value distribution of Duration_hours can be visualize
sns.distplot(train_data['Duration_hours'])
sns.boxplot(y=train_data['Duration_hours'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Value distribution
train_data.Duration_mins.value_counts()
# Out:
# 30    1421
# 0     1005
# 20     979
# 50     950
# 35     930
# 15     884
# 45     874
# 55     856
# 25     801
# 40     622
# 5      620
# 10     520
# Name: Duration_mins, dtype: int64

# %%
# value distribution of Duration_mins can be visualize
sns.distplot(train_data['Duration_mins'])
sns.boxplot(y=train_data['Duration_mins'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Handling Categorical Data

# %%
# To look the statistics of categorical data

train_data.describe(include='O')
# Out:
#             Airline Source Destination            Route Total_Stops  \
# count         10462  10462       10462            10462       10462
# unique           12      5           6              128           5
# top     Jet Airways  Delhi      Cochin  DEL → BOM → COK      1 stop
# freq           3700   4345        4345             2376        5625
#
#        Additional_Info
# count            10462
# unique              10
# top            No info
# freq              8182

# %% [markdown]
# Working on 'Airline' column

# %%
# For unique values in the Airline column

train_data['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
# For frequencies

train_data['Airline'].value_counts()
# Out:
# Jet Airways                          3700
# IndiGo                               2043
# Air India                            1694
# Multiple carriers                    1196
# SpiceJet                              815
# Vistara                               478
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
# to detect outliers and statistical analysis

plt.figure(figsize=(20,10))
ax=sns.boxplot(y='Price',x='Airline',data=train_data.sort_values('Price',ascending=False))
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
plt.show()

# %% [markdown]
# Working on 'Source' column

# %%
# To find out unique values as well as its frequency

train_data['Source'].value_counts()
# Out:
# Delhi       4345
# Kolkata     2860
# Banglore    2179
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
# to detect outliers and statistical analysis

plt.figure(figsize=(15,8))
sns.boxplot(y='Price',x='Source',data=train_data.sort_values('Price',ascending=False,))
plt.show()

# %% [markdown]
# Working on 'Destination' column

# %%
# to find out unique values and its frequency  

train_data['Destination'].value_counts()
# Out:
# Cochin       4345
# Banglore     2860
# Delhi        1265
# New Delhi     914
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
# to detect outliers and statistical analysis

plt.figure(figsize=(15,8))
sns.boxplot(y='Price',x='Destination',data=train_data.sort_values('Price',ascending=False))
plt.show()

# %% [markdown]
# Working on 'Route' and 'Additional_Info' column

# %%
train_data['Route']
# Out:
# 0                    BLR → DEL
# 1        CCU → IXR → BBI → BLR
# 2        DEL → LKO → BOM → COK
# 3              CCU → NAG → BLR
# 4              BLR → NAG → DEL
#                  ...
# 10457                CCU → BLR
# 10458                CCU → BLR
# 10459                BLR → DEL
# 10460                BLR → DEL
# 10461    DEL → GOI → BOM → COK
# Name: Route, Length: 10462, dtype: object

# %%
# Since 'Route' and 'Total_Stops' contain same information
# Also Additional_Info contains almost no_info

train_data.drop(columns=['Route','Additional_Info'],inplace=True)

# %%
train_data.head()
# Out:
#        Airline    Source Destination Total_Stops  Price  Journey_day  \
# 0       IndiGo  Banglore   New Delhi    non-stop   3897           24
# 1    Air India   Kolkata    Banglore     2 stops   7662            1
# 2  Jet Airways     Delhi      Cochin     2 stops  13882            9
# 3       IndiGo   Kolkata    Banglore      1 stop   6218           12
# 4       IndiGo  Banglore   New Delhi      1 stop  13302            1
#
#    Journey_month  Dep_hour  Dep_min  Arrival_hour  Arrival_min  \
# 0              3        22       20             1           10
# 1              5         5       50            13           15
# 2              6         9       25             4           25
# 3              5        18        5            23           30
# 4              3        16       50            21           35
#
#    Duration_hours  Duration_mins
# 0               2             50
# 1               7             25
# 2              19              0
# ...

# %% [markdown]
# Working on 'Total_Stops' column

# %%
# to find out unique values and its frequency  

train_data['Total_Stops'].value_counts()
# Out:
# 1 stop      5625
# non-stop    3475
# 2 stops     1318
# 3 stops       43
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
# As this is a case of Ordinal Categorical type, so we perform LabelEncoder
# Here Values are assigned with corresponding keys

train_data.replace({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4},inplace=True)

# %%
# Recheck values

train_data['Total_Stops'].value_counts()
# Out:
# 1    5625
# 0    3475
# 2    1318
# 3      43
# 4       1
# Name: Total_Stops, dtype: int64

# %%
train_data.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_month  Dep_hour  Dep_min  Arrival_hour  Arrival_min  \
# 0              3        22       20             1           10
# 1              5         5       50            13           15
# 2              6         9       25             4           25
# 3              5        18        5            23           30
# 4              3        16       50            21           35
#
#    Duration_hours  Duration_mins
# 0               2             50
# 1               7             25
# 2              19              0
# ...

# %%
# Using get_dummies() convert the Nominal Categorical data 

train_data= pd.get_dummies(train_data,columns=['Airline','Source','Destination'],drop_first=True)

# %%
train_data.head()
# Out:
#    Total_Stops  Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0            0   3897           24              3        22       20
# 1            2   7662            1              5         5       50
# 2            2  13882            9              6         9       25
# 3            1   6218           12              5        18        5
# 4            1  13302            1              3        16       50
#
#    Arrival_hour  Arrival_min  Duration_hours  Duration_mins  \
# 0             1           10               2             50
# 1            13           15               7             25
# 2             4           25              19              0
# 3            23           30               5             25
# 4            21           35               4             45
#
#    Airline_Air India  Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 0                  0              0               1                    0
# ...

# %%
# To check Shape

train_data.shape
# Out:
# (10462, 30)

# %%
# To see the correlation 

train_data.corr()
# Out:
#                                            Total_Stops     Price  Journey_day  \
# Total_Stops                                   1.000000  0.602013    -0.018937
# Price                                         0.602013  1.000000    -0.159044
# Journey_day                                  -0.018937 -0.159044     1.000000
# Journey_month                                 0.039003 -0.113396    -0.038331
# Dep_hour                                     -0.067523  0.005155    -0.003394
# Dep_min                                      -0.002695 -0.024155    -0.004741
# Arrival_hour                                  0.051476  0.031023    -0.002448
# Arrival_min                                  -0.107099 -0.086163    -0.015086
# Duration_hours                                0.730156  0.504200    -0.029382
# Duration_mins                                -0.150253 -0.131664    -0.009244
# Airline_Air India                             0.272543  0.050357    -0.031830
# ...

# %% [markdown]
# ## Test_set

# %%
# To fetch excel file

test_data=pd.read_excel('Test_set.xlsx')

# %%
test_data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
# To get information of column's datatypes

test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB

# %%
# To see different values and its frequency

test_data['Duration'].value_counts()
# Out:
# 2h 50m     122
# 1h 30m     107
# 2h 45m      95
# 2h 55m      81
# 3h          72
#           ...
# 7h 10m       1
# 17h 40m      1
# 3h 45m       1
# 19h 45m      1
# 38h 35m      1
# Name: Duration, Length: 320, dtype: int64

# %%
# To check null values

test_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %%
# Shape of DataFrame

test_data.shape
# Out:
# (2671, 10)

# %%
# To remove Duplicate

test_data.drop_duplicates(inplace=True)

# %%
# To index again

test_data.reset_index(inplace=True,drop=True)

# %%
# Final shape after removing duplicates

test_data.shape
# Out:
# (2645, 10)

# %%
test_data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2645 entries, 0 to 2644
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2645 non-null   object
#  1   Date_of_Journey  2645 non-null   object
#  2   Source           2645 non-null   object
#  3   Destination      2645 non-null   object
#  4   Route            2645 non-null   object
#  5   Dep_Time         2645 non-null   object
#  6   Arrival_Time     2645 non-null   object
#  7   Duration         2645 non-null   object
#  8   Total_Stops      2645 non-null   object
#  9   Additional_Info  2645 non-null   object
# dtypes: object(10)
# memory usage: 206.8+ KB

# %% [markdown]
#  # Convert the object datatypes to useful datatype

# %%
test_data['Journey_day']=pd.to_datetime(test_data.Date_of_Journey,dayfirst=True).dt.day
test_data['Journey_month']=pd.to_datetime(test_data.Date_of_Journey,dayfirst=True).dt.month

# %%
test_data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Journey_day  Journey_month
# ...

# %%
# After fetching all the information from Date_of_Journey column, it should be deleted

test_data.drop(columns=['Date_of_Journey'],inplace=True)

# %%
# Convert Dep_Time into datetime datatype

test_data['Dep_hour']=pd.to_datetime(test_data.Dep_Time).dt.hour
test_data['Dep_min']=pd.to_datetime(test_data.Dep_Time).dt.minute

# %%
# Remove Dep_Time column

test_data.drop(columns=['Dep_Time'],inplace=True)

# %%
test_data.head()
# Out:
#              Airline    Source Destination            Route  Arrival_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  04:25 07 Jun
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR         10:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  19:00 22 May
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK         21:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL  02:45 25 Jun
#
#   Duration Total_Stops              Additional_Info  Journey_day  \
# 0  10h 55m      1 stop                      No info            6
# 1       4h      1 stop                      No info           12
# 2  23h 45m      1 stop  In-flight meal not included           21
# 3      13h      1 stop                      No info           21
# 4   2h 50m    non-stop                      No info           24
#
#    Journey_month  Dep_hour  Dep_min
# 0              6        17       30
# 1              5         6       20
# ...

# %%
# Convert Arrival_Time into datetime datatype

test_data['Arrival_hour']=pd.to_datetime(test_data.Arrival_Time).dt.hour
test_data['Arrival_min']=pd.to_datetime(test_data.Arrival_Time).dt.minute

# %%
# Removing Arrival_Time column

test_data.drop(columns=['Arrival_Time'],inplace=True)

# %%
test_data.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#   Total_Stops              Additional_Info  Journey_day  Journey_month  \
# 0      1 stop                      No info            6              6
# 1      1 stop                      No info           12              5
# 2      1 stop  In-flight meal not included           21              5
# 3      1 stop                      No info           21              5
# 4    non-stop                      No info           24              6
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min
# 0        17       30             4           25
# ...

# %%
# to make hour and minute columns separately from Duration column

duration = list(test_data['Duration'])

for i in range(len(duration)):
  if len(duration[i].split()) !=2:                # checks if duration contain only hour or min
    if 'h' in duration[i]:
      duration[i] = duration[i].strip() + ' 0m'   # add 0 minute
    else:
      duration[i] = '0h ' + duration[i]           # add 0 hour
  else:
    continue

duration_hour=[]
duration_min=[]
for i in range(len(duration)):
  duration_hour.append(int(duration[i].split('h')[0]))                     # Extract hour from duration
  duration_min.append(int(duration[i].split()[1].split('m')[0]))           # Extract minute from duration

# %%
# Make columns and assigning the values

test_data['Duration_hours']=duration_hour
test_data['Duration_mins']=duration_min

# %%
# Remove Duration Column
test_data.drop(columns=['Duration'],inplace=True)

# %%
test_data.head()
# Out:
#              Airline    Source Destination            Route Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR      1 stop
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      1 stop
# 4           Air Asia  Banglore       Delhi        BLR → DEL    non-stop
#
#                Additional_Info  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0                      No info            6              6        17       30
# 1                      No info           12              5         6       20
# 2  In-flight meal not included           21              5        19       15
# 3                      No info           21              5         8        0
# 4                      No info           24              6        23       55
#
#    Arrival_hour  Arrival_min  Duration_hours  Duration_mins
# ...

# %% [markdown]
# # Handling Categorical Data

# %%
# To look the statistics of categorical data

test_data.describe(include='O')
# Out:
#             Airline Source Destination            Route Total_Stops  \
# count          2645   2645        2645             2645        2645
# unique           11      5           6              100           5
# top     Jet Airways  Delhi      Cochin  DEL → BOM → COK      1 stop
# freq            886   1127        1127              620        1427
#
#        Additional_Info
# count             2645
# unique               6
# top            No info
# freq              2126

# %%
# For unique values

test_data['Airline'].unique()
# Out:
# array(['Jet Airways', 'IndiGo', 'Multiple carriers', 'Air Asia',
#        'Air India', 'Vistara', 'SpiceJet', 'Vistara Premium economy',
#        'GoAir', 'Multiple carriers Premium economy',
#        'Jet Airways Business'], dtype=object)

# %%
# For frequency

test_data['Airline'].value_counts()
# Out:
# Jet Airways                          886
# IndiGo                               509
# Air India                            432
# Multiple carriers                    343
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 45
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Jet Airways Business                   2
# Name: Airline, dtype: int64

# %%
# To find out unique values as well as its frequency

test_data['Source'].value_counts()
# Out:
# Delhi       1127
# Kolkata      707
# Banglore     550
# Mumbai       186
# Chennai       75
# Name: Source, dtype: int64

# %%
# To find out unique values as well as its frequency

test_data['Destination'].value_counts()
# Out:
# Cochin       1127
# Banglore      707
# Delhi         317
# New Delhi     233
# Hyderabad     186
# Kolkata        75
# Name: Destination, dtype: int64

# %%
# 'Route' and 'Additional_Info should be removed

test_data.drop(columns=['Route','Additional_Info'],inplace=True)

# %%
test_data.head()
# Out:
#              Airline    Source Destination Total_Stops  Journey_day  \
# 0        Jet Airways     Delhi      Cochin      1 stop            6
# 1             IndiGo   Kolkata    Banglore      1 stop           12
# 2        Jet Airways     Delhi      Cochin      1 stop           21
# 3  Multiple carriers     Delhi      Cochin      1 stop           21
# 4           Air Asia  Banglore       Delhi    non-stop           24
#
#    Journey_month  Dep_hour  Dep_min  Arrival_hour  Arrival_min  \
# 0              6        17       30             4           25
# 1              5         6       20            10           20
# 2              5        19       15            19            0
# 3              5         8        0            21            0
# 4              6        23       55             2           45
#
#    Duration_hours  Duration_mins
# 0              10             55
# 1               4              0
# 2              23             45
# 3              13              0
# ...

# %%
# To findout unique values and frequency

test_data['Total_Stops'].value_counts()
# Out:
# 1 stop      1427
# non-stop     846
# 2 stops      360
# 3 stops       11
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
# Replacing the values

test_data.replace({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4},inplace=True)

# %%
# Recheck values

test_data['Total_Stops'].value_counts()
# Out:
# 1    1427
# 0     846
# 2     360
# 3      11
# 4       1
# Name: Total_Stops, dtype: int64

# %%
# Using get_dummies() convert the Nominal aCategorical data

test_data=pd.get_dummies(test_data,columns=['Airline','Source','Destination'],drop_first=True)

# %%
test_data.head()
# Out:
#    Total_Stops  Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour  \
# 0            1            6              6        17       30             4
# 1            1           12              5         6       20            10
# 2            1           21              5        19       15            19
# 3            1           21              5         8        0            21
# 4            0           24              6        23       55             2
#
#    Arrival_min  Duration_hours  Duration_mins  Airline_Air India  \
# 0           25              10             55                  0
# 1           20               4              0                  0
# 2            0              23             45                  0
# 3            0              13              0                  0
# 4           45               2             50                  0
#
#    Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 0              0               0                    1
# ...

# %%
# To check shape

test_data.shape
# Out:
# (2645, 28)

# %% [markdown]
# #find out the best feature which will contribute and have good relation with target variable

# %%
train_data.shape
# Out:
# (10462, 30)

# %%
train_data.columns
# Out:
# Index(['Total_Stops', 'Price', 'Journey_day', 'Journey_month', 'Dep_hour',
#        'Dep_min', 'Arrival_hour', 'Arrival_min', 'Duration_hours',
#        'Duration_mins', 'Airline_Air India', 'Airline_GoAir', 'Airline_IndiGo',
#        'Airline_Jet Airways', 'Airline_Jet Airways Business',
#        'Airline_Multiple carriers',
#        'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
#        'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
#        'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
#        'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
#        'Destination_Kolkata', 'Destination_New Delhi'],
#       dtype='object')

# %%
x=train_data.loc[:,['Total_Stops', 'Journey_day', 'Journey_month', 'Dep_hour',
       'Dep_min', 'Arrival_hour', 'Arrival_min', 'Duration_hours',
       'Duration_mins', 'Airline_Air India', 'Airline_GoAir',
       'Airline_IndiGo', 'Airline_Jet Airways',
       'Airline_Jet Airways Business', 'Airline_Multiple carriers',
       'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
       'Airline_Trujet', 'Airline_Vistara',
       'Airline_Vistara Premium economy', 'Source_Chennai',
       'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
       'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
       'Destination_Kolkata', 'Destination_New Delhi']]

# %%
x.head()
# Out:
#    Total_Stops  Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour  \
# 0            0           24              3        22       20             1
# 1            2            1              5         5       50            13
# 2            2            9              6         9       25             4
# 3            1           12              5        18        5            23
# 4            1            1              3        16       50            21
#
#    Arrival_min  Duration_hours  Duration_mins  Airline_Air India  \
# 0           10               2             50                  0
# 1           15               7             25                  1
# 2           25              19              0                  0
# 3           30               5             25                  0
# 4           35               4             45                  0
#
#    Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 0              0               1                    0
# ...

# %%
y=train_data.iloc[:,1]

# %%
y.head()
# Out:
# 0     3897
# 1     7662
# 2    13882
# 3     6218
# 4    13302
# Name: Price, dtype: int64

# %%
# Finds correlation between Independent and Dependent attributes

plt.figure(figsize=(35,20))
sns.heatmap(train_data.corr(),annot=True,cmap='RdYlGn')
plt.show()
